# %%
import os
import json
import pyperclip
import pandas as pd

# %%
DATA_PATH = os.path.join('../Apple Music Activity')
FILE_NAME = 'Apple Music - Recent Impressions.csv'
DOCS_PATH = os.path.join('../docs/Library')
# DOC_NAME = 'LIBRARY_ACTIVITY.md'

# %%
df = pd.read_csv(os.path.join(DATA_PATH, FILE_NAME))

# %%
df.shape
# Out:
# (1280, 5)

# %%
df.columns
# Out:
# Index(['Country', 'Container Name', 'Impression Create Date', 'Location',
#        'Recommendation ID'],
#       dtype='object')

# %%
df.head()
# Out:
#          Country               Container Name  Impression Create Date  \
# 0  United States  Money Musik - MONEY MILITIA                20250504
# 1  United States                          NaN                20250504
# 2  United States                          NaN                20250504
# 3  United States                          NaN                20250504
# 4  United States                          NaN                20250504
#
#                              Location  \
# 0  FUSE.ForYou.Module.Recently.Played
# 1  FUSE.ForYou.Module.Recently.Played
# 2  FUSE.ForYou.Module.Recently.Played
# 3  FUSE.ForYou.Module.Recently.Played
# 4                  FY.Module.TopPicks
#
#                                    Recommendation ID
# 0  b4c66aa4-9e0f-480d-82af-d816dc582491~0b5e03e0-...
# 1  b4c66aa4-9e0f-480d-82af-d816dc582491~0b5e03e0-...
# 2  b4c66aa4-9e0f-480d-82af-d816dc582491~0b5e03e0-...
# 3  b4c66aa4-9e0f-480d-82af-d816dc582491~0b5e03e0-...
# ...

# %%
df.sort_values(by='Impression Create Date', ascending=True)
# Out:
#             Country               Container Name  Impression Create Date  \
# 1279  United States                          NaN                20250306
# 1273  United States                          NaN                20250306
# 1274  United States                          NaN                20250306
# 1278  United States                          NaN                20250306
# 1276  United States                          NaN                20250306
# ...             ...                          ...                     ...
# 4     United States                          NaN                20250504
# 3     United States                          NaN                20250504
# 2     United States                          NaN                20250504
# 1     United States                          NaN                20250504
# 0     United States  Money Musik - MONEY MILITIA                20250504
#
#                                 Location  \
# 1279             FY.Module.YourFavorites
# ...

# %%
df['Container Name'].unique()
# Out:
# array(['Money Musik - MONEY MILITIA', nan, 'Favorites Mix',
#        'Charli xcx - CRASH', 'Camila Cabello - Familia', 'DJ SA Radio',
#        'Chill Mix', 'Yashraj - LADKE CONVICT - Single',
#        'Loka - Loka Kaha Hai (Side A) - EP', 'Jack Harlow Radio',
#        'Ed Sheeran - Play', 'MIKE DEAN - 425',
#        'Quavo & Takeoff - Dope Boy Phone - Single',
#        'Lil Baby, Young Thug & Future - Dum, Dumb, and Dumber - Single',
#        'Werenoi & Gunna - Gulfstream - Single',
#        'Young Thug - Money On Money (feat. Future) - Single',
#        'Daft Punk - Random Access Memories',
#        'PFV - Hail Mary (Deluxe Edition)', 'KATSEYE - Gnarly - Single',
#        'Ritviz - Mimmi', 'Seedhe Maut - Lunch Break', 'Bharg - Nikamma',
#        'Jamie xx - In Colour', 'Swedish House Mafia - Paradise Again',
#        'Rawal & Bharg - Sab Chahiye', 'The Local Train - Aalas Ka Pedh',
#        'King - BAWE MAIN CHECK - EP', 'KR$NA - For The Day One$ - EP',
# ...

# %%
df['Container Name'].nunique()
# Out:
# 362
