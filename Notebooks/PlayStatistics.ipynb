# %%
import os
import json
import pyperclip
import pandas as pd

# %%
DATA_PATH = os.path.join('../Apple Music Activity')
FILE_NAME = 'Apple Music - Play Statistics.csv'
DOCS_PATH = os.path.join('../docs/Library')
# DOC_NAME = 'LIBRARY_ACTIVITY.md'

# %%
df = pd.read_csv(os.path.join(DATA_PATH, FILE_NAME))

# %%
df.shape
# Out:
# (361, 5)

# %%
df.columns
# Out:
# Index(['Play Duration Milliseconds', 'First Played', 'Last Played',
#        'Source Type', 'Date Created'],
#       dtype='object')

# %%
df.head()
# Out:
#    Play Duration Milliseconds   First Played    Last Played  \
# 0                      109646  1746491004520  1746491114166
# 1                    10769500  1746407424817  1746477008514
# 2                    10528236  1746049947283  1746397360127
# 3                    12465002  1746235770037  1746309847387
# 4                    12733085  1746145786646  1746223102147
#
#          Source Type  Date Created
# 0             IPHONE      20250506
# 1             IPHONE      20250505
# 2  IPHONE, MACINTOSH      20250504
# 3             IPHONE      20250503
# 4             IPHONE      20250502

# %%
df.sort_values(by='Date Created', ascending=True)
# Out:
#      Play Duration Milliseconds   First Played    Last Played  \
# 360                    15209863  1714954571213  1715028540159
# 359                     6631331  1715042453920  1715129686359
# 358                    13572857  1715129687216  1715208519045
# 357                     9537119  1715213283778  1715300336033
# 356                    17821325  1715300341697  1715381633212
# ..                          ...            ...            ...
# 4                      12733085  1746145786646  1746223102147
# 3                      12465002  1746235770037  1746309847387
# 2                      10528236  1746049947283  1746397360127
# 1                      10769500  1746407424817  1746477008514
# 0                        109646  1746491004520  1746491114166
#
#            Source Type  Date Created
# 360             IPHONE      20240506
# 359             IPHONE      20240507
# 358             IPHONE      20240508
# 357  IPHONE, MACINTOSH      20240509
# 356             IPHONE      20240510
# ..                 ...           ...
# 4               IPHONE      20250502
# 3               IPHONE      20250503
# 2    IPHONE, MACINTOSH      20250504
# 1               IPHONE      20250505
# 0               IPHONE      20250506
#
# [361 rows x 5 columns]
