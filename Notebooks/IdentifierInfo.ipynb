# %%
import os
import json
import pandas as pd

# %%
DATA_PATH = os.path.join('../Apple Music Activity')
FILE_NAME = 'Identifier Information.json'
DOCS_PATH = os.path.join('../docs/Library')
DOC_NAME = 'IDENTIFIER_ID.md'

# %%
with open(os.path.join(DATA_PATH, FILE_NAME), 'r') as f:
    library = json.load(f)

# %%
len(library), type(library)
# Out:
# (5196, list)

# %%
# key_len = set()
# for item in library:
#     key_len.add(len(item.keys()))
    
# print (key_len)
# Out:
# {2}

# %%
df = pd.DataFrame(library)

# %%
df.shape
# Out:
# (5196, 2)

# %%
df.columns
# Out:
# Index(['Identifier', 'Title'], dtype='object')

# %%
df['Title'].value_counts()

# MAJOR: Indicates that there is mutliple Identifier id for same title (song)
# Out:
# Title
# Hand Up (Bass Boosted)                       7
# Turn On The Lights again.. (feat. Future)    6
# Jungle                                       5
# After Hours                                  5
# Just Wanna Rock                              4
#                                             ..
# Push Ups                                     1
# Mithoon                                      1
# Might Delete Later                           1
# Walk                                         1
# 3:59 AM                                      1
# Name: count, Length: 4670, dtype: int64
