# %%
import os
import json
import pyperclip
import pandas as pd

# %%
DATA_PATH = os.path.join('../Apple Music Activity')
FILE_NAME = 'Apple Music Library Playlists.json'
DOCS_PATH = os.path.join('../docs/Library')
DOC_NAME = 'LIBRARY_PLAYLISTS.md'

# %%
with open(os.path.join(DATA_PATH, FILE_NAME), 'r') as f:
    library = json.load(f)

# %%
len(library), type(library)
# Out:
# (106, list)

# %%
library[0].keys()
# Out:
# dict_keys(['Container Type', 'Container Identifier', 'Title', 'Playlist Item Identifiers', 'Favorite Status - Playlist', 'Favorite Date - Playlist', 'Added Date', 'Name or Description Modified Date', 'Playlist Items Modified Date'])

# %%
keys_set = set()
for item in library:
    keys_set.add(len(item.keys()))
keys_set
# Out:
# {6, 7, 8, 9, 10, 11, 12}

# %%
types_set = set()
list_type_keyset = set()
for item in library:
    for key in item.keys():
        types_set.add(type(item[key]))
        if type(item[key]) == list:
            list_type_keyset.add(key)
        
types_set, list_type_keyset
# Out:
# ({bool, int, list, str}, {'Playlist Item Identifiers'})

# %%
df = pd.DataFrame(library)

# %%
df.shape
# Out:
# (106, 14)

# %%
df.columns
# Out:
# Index(['Container Type', 'Container Identifier', 'Title',
#        'Playlist Item Identifiers', 'Favorite Status - Playlist',
#        'Favorite Date - Playlist', 'Added Date',
#        'Name or Description Modified Date', 'Playlist Items Modified Date',
#        'Public Playlist Identifier', 'Playlist Is Shared',
#        'Playlist Previously Shared', 'Description',
#        'Available On Apple Music Profile'],
#       dtype='object')

# %%
df['Container Type'].value_counts()
# Out:
# Container Type
# Playlist               53
# Subscribed Playlist    52
# Favorites Playlist      1
# Name: count, dtype: int64

# %%
df['Container Type'].isna().sum()
# Out:
# 0

# %%
df['Container Identifier'].isna().sum()
# Out:
# 0

# %%
df['Container Identifier'].value_counts()
# Out:
# Container Identifier
# 2            1
# 256004113    1
# 256004105    1
# 256004101    1
# 256004097    1
#             ..
# 256001801    1
# 256001797    1
# 256001793    1
# 256001553    1
# 256005633    1
# Name: count, Length: 106, dtype: int64

# %%
df['Title'].isna().sum()
# Out:
# 52

# %%
df[df['Title'].isna()]
# Out:
#           Container Type  Container Identifier Title  \
# 1    Subscribed Playlist             256000261   NaN
# 2    Subscribed Playlist             256000265   NaN
# 3    Subscribed Playlist             256000269   NaN
# 4    Subscribed Playlist             256000273   NaN
# 5    Subscribed Playlist             256000513   NaN
# 10   Subscribed Playlist             256000769   NaN
# 11   Subscribed Playlist             256000773   NaN
# 12   Subscribed Playlist             256000777   NaN
# 13   Subscribed Playlist             256000781   NaN
# 14   Subscribed Playlist             256000785   NaN
# 15   Subscribed Playlist             256001025   NaN
# 16   Subscribed Playlist             256001029   NaN
# 18   Subscribed Playlist             256001037   NaN
# 20   Subscribed Playlist             256001281   NaN
# 21   Subscribed Playlist             256001285   NaN
# 24   Subscribed Playlist             256001297   NaN
# 27   Subscribed Playlist             256001545   NaN
# 28   Subscribed Playlist             256001549   NaN
# 33   Subscribed Playlist             256001805   NaN
# 41   Subscribed Playlist             256002309   NaN
# 42   Subscribed Playlist             256002313   NaN
# 43   Subscribed Playlist             256002317   NaN
# 45   Subscribed Playlist             256002561   NaN
# 46   Subscribed Playlist             256002565   NaN
# 47   Subscribed Playlist             256002569   NaN
# 49   Subscribed Playlist             256002577   NaN
# 50   Subscribed Playlist             256002817   NaN
# 51   Subscribed Playlist             256002821   NaN
# 52   Subscribed Playlist             256002825   NaN
# 54   Subscribed Playlist             256002833   NaN
# 55   Subscribed Playlist             256003073   NaN
# 60   Subscribed Playlist             256003329   NaN
# 61   Subscribed Playlist             256003333   NaN
# 62   Subscribed Playlist             256003337   NaN
# 63   Subscribed Playlist             256003341   NaN
# 64   Subscribed Playlist             256003345   NaN
# 65   Subscribed Playlist             256003585   NaN
# 66   Subscribed Playlist             256003589   NaN
# 67   Subscribed Playlist             256003593   NaN
# 74   Subscribed Playlist             256003857   NaN
# 76   Subscribed Playlist             256004101   NaN
# 77   Subscribed Playlist             256004105   NaN
# 78   Subscribed Playlist             256004109   NaN
# 82   Subscribed Playlist             256004361   NaN
# 84   Subscribed Playlist             256004369   NaN
# 85   Subscribed Playlist             256004609   NaN
# 86   Subscribed Playlist             256004613   NaN
# 87   Subscribed Playlist             256004617   NaN
# 91   Subscribed Playlist             256004869   NaN
# 96   Subscribed Playlist             256005125   NaN
# 99   Subscribed Playlist             256005137   NaN
# 105  Subscribed Playlist             256005633   NaN
#
#     Playlist Item Identifiers Favorite Status - Playlist  \
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# 10                        NaN                        NaN
# 11                        NaN                        NaN
# 12                        NaN                        NaN
# 13                        NaN                        NaN
# 14                        NaN                        NaN
# 15                        NaN                        NaN
# 16                        NaN                        NaN
# 18                        NaN                       True
# 20                        NaN                        NaN
# 21                        NaN                        NaN
# 24                        NaN                        NaN
# 27                        NaN                        NaN
# 28                        NaN                        NaN
# 33                        NaN                        NaN
# 41                        NaN                        NaN
# 42                        NaN                        NaN
# 43                        NaN                        NaN
# 45                        NaN                        NaN
# 46                        NaN                        NaN
# 47                        NaN                        NaN
# 49                        NaN                        NaN
# 50                        NaN                        NaN
# 51                        NaN                        NaN
# 52                        NaN                        NaN
# 54                        NaN                        NaN
# 55                        NaN                        NaN
# 60                        NaN                        NaN
# 61                        NaN                        NaN
# 62                        NaN                        NaN
# 63                        NaN                        NaN
# 64                        NaN                        NaN
# 65                        NaN                        NaN
# 66                        NaN                        NaN
# 67                        NaN                        NaN
# 74                        NaN                        NaN
# 76                        NaN                        NaN
# 77                        NaN                        NaN
# 78                        NaN                        NaN
# 82                        NaN                        NaN
# 84                        NaN                        NaN
# 85                        NaN                        NaN
# 86                        NaN                        NaN
# 87                        NaN                        NaN
# 91                        NaN                        NaN
# 96                        NaN                        NaN
# 99                        NaN                        NaN
# 105                       NaN                        NaN
#
#     Favorite Date - Playlist            Added Date  \
# 1                        NaN  2021-03-18T08:48:19Z
# 2                        NaN  2021-04-16T18:37:21Z
# 3                        NaN  2021-04-18T06:30:46Z
# 4                        NaN  2021-04-21T17:39:04Z
# 5                        NaN  2021-05-08T22:28:39Z
# 10                       NaN  2021-06-18T17:13:00Z
# 11                       NaN  2021-06-18T17:21:49Z
# 12                       NaN  2021-06-23T07:08:33Z
# 13                       NaN  2021-06-30T16:43:08Z
# 14                       NaN  2021-06-30T16:45:04Z
# 15                       NaN  2021-07-02T09:59:43Z
# 16                       NaN  2021-07-12T23:29:58Z
# 18                       NaN  2021-08-06T06:43:23Z
# 20                       NaN  2021-08-18T19:20:19Z
# 21                       NaN  2021-08-19T07:04:16Z
# 24                       NaN  2021-10-08T18:47:10Z
# 27                       NaN  2021-12-01T17:42:53Z
# 28                       NaN  2022-02-18T22:13:04Z
# 33                       NaN  2022-04-27T10:45:39Z
# 41                       NaN  2022-10-01T12:07:22Z
# 42                       NaN  2022-10-03T06:18:34Z
# 43                       NaN  2022-10-03T06:18:52Z
# 45                       NaN  2022-11-01T23:39:22Z
# 46                       NaN  2022-11-02T00:50:03Z
# 47                       NaN  2022-11-02T08:51:13Z
# 49                       NaN  2022-11-12T19:01:46Z
# 50                       NaN  2022-11-29T21:29:12Z
# 51                       NaN  2023-02-15T08:08:16Z
# 52                       NaN  2022-12-16T20:12:42Z
# 54                       NaN  2022-12-20T18:56:44Z
# 55                       NaN  2023-01-27T18:08:32Z
# 60                       NaN  2023-03-27T18:42:56Z
# 61                       NaN  2023-04-12T20:01:21Z
# 62                       NaN  2023-04-13T09:57:43Z
# 63                       NaN  2023-04-13T10:07:29Z
# 64                       NaN  2023-04-13T10:15:45Z
# 65                       NaN  2023-04-13T19:21:22Z
# 66                       NaN  2023-04-13T19:25:27Z
# 67                       NaN  2023-04-13T19:55:03Z
# 74                       NaN  2023-05-25T19:53:46Z
# 76                       NaN  2023-06-21T00:29:09Z
# 77                       NaN  2023-06-23T18:43:09Z
# 78                       NaN  2023-06-30T06:34:56Z
# 82                       NaN  2023-08-11T01:55:57Z
# 84                       NaN  2023-09-21T19:09:46Z
# 85                       NaN  2023-11-08T07:41:35Z
# 86                       NaN  2023-11-22T01:26:53Z
# 87                       NaN  2023-11-22T01:27:33Z
# 91                       NaN  2024-03-07T04:25:16Z
# 96                       NaN  2024-04-16T18:15:13Z
# 99                       NaN  2024-05-01T16:13:49Z
# 105                      NaN  2024-07-28T15:23:12Z
#
#     Name or Description Modified Date Playlist Items Modified Date  \
# 1                2021-03-18T08:48:19Z         2021-03-18T08:48:19Z
# 2                2021-04-16T18:37:21Z         2021-04-16T18:37:21Z
# 3                2021-04-18T06:30:46Z         2021-04-18T06:30:46Z
# 4                2021-04-21T17:39:04Z         2021-04-21T17:39:04Z
# 5                2021-05-08T22:28:39Z         2021-05-08T22:28:39Z
# 10               2021-06-18T17:13:00Z         2021-06-18T17:13:00Z
# 11               2021-06-18T17:21:49Z         2021-06-18T17:21:49Z
# 12               2021-06-23T07:08:33Z         2021-06-23T07:08:33Z
# 13               2021-06-30T16:43:08Z         2021-06-30T16:43:08Z
# 14               2021-06-30T16:45:04Z         2021-06-30T16:45:04Z
# 15               2021-07-02T09:59:43Z         2021-07-02T09:59:43Z
# 16               2021-07-12T23:29:58Z         2021-07-12T23:29:58Z
# 18               2021-08-06T06:43:23Z         2021-08-06T06:43:23Z
# 20               2021-08-18T19:20:19Z         2021-08-18T19:20:19Z
# 21               2021-08-19T07:04:16Z         2021-08-19T07:04:16Z
# 24               2021-10-08T18:47:10Z         2021-10-08T18:47:10Z
# 27               2021-12-01T17:42:53Z         2021-12-01T17:42:53Z
# 28               2022-02-18T22:13:04Z         2022-02-18T22:13:04Z
# 33               2022-04-27T10:45:39Z         2022-04-27T10:45:39Z
# 41               2022-10-01T12:07:22Z         2022-10-01T12:07:22Z
# 42               2022-10-03T06:18:34Z         2022-10-03T06:18:34Z
# 43               2022-10-03T06:18:52Z         2022-10-03T06:18:52Z
# 45               2022-11-01T23:39:22Z         2022-11-01T23:39:22Z
# 46               2022-11-02T00:50:03Z         2022-11-02T00:50:03Z
# 47               2022-11-02T08:51:13Z         2022-11-02T08:51:13Z
# 49               2022-11-12T19:01:46Z         2022-11-12T19:01:46Z
# 50               2022-11-29T21:29:12Z         2022-11-29T21:29:12Z
# 51               2022-12-02T21:14:56Z         2022-12-02T21:14:56Z
# 52               2022-12-16T20:12:42Z         2022-12-16T20:12:42Z
# 54               2022-12-20T18:56:44Z         2022-12-20T18:56:44Z
# 55               2023-01-27T18:08:32Z         2023-01-27T18:08:32Z
# 60               2023-03-27T18:42:56Z         2023-03-27T18:42:56Z
# 61               2023-04-12T20:01:21Z         2023-04-12T20:01:21Z
# 62               2023-04-13T09:57:43Z         2023-04-13T09:57:43Z
# 63               2023-04-13T10:07:29Z         2023-04-13T10:07:29Z
# 64               2023-04-13T10:15:45Z         2023-04-13T10:15:45Z
# 65               2023-04-13T19:21:22Z         2023-04-13T19:21:22Z
# 66               2023-04-13T19:25:27Z         2023-04-13T19:25:27Z
# 67               2023-04-13T19:55:03Z         2023-04-13T19:55:03Z
# 74               2023-05-25T19:53:46Z         2023-05-25T19:53:46Z
# 76               2023-06-21T00:29:09Z         2023-06-21T00:29:09Z
# 77               2023-06-23T18:43:09Z         2023-06-23T18:43:09Z
# 78               2023-06-30T06:34:56Z         2023-06-30T06:34:56Z
# 82               2023-08-11T01:55:57Z         2023-08-11T01:55:57Z
# 84               2023-09-21T19:09:46Z         2023-09-21T19:09:46Z
# 85               2023-11-08T07:41:35Z         2023-11-08T07:41:35Z
# 86                                NaN                          NaN
# 87               2024-03-22T03:38:44Z                          NaN
# 91               2024-03-07T04:25:16Z         2024-03-07T04:25:16Z
# 96               2024-04-16T18:15:13Z         2024-04-16T18:15:13Z
# 99               2024-05-01T16:13:49Z         2024-05-01T16:13:49Z
# 105              2024-07-28T15:23:12Z         2024-07-28T15:23:12Z
#
#                  Public Playlist Identifier Playlist Is Shared  \
# 1                       pl.u-9N9L8abt7ArvWB               True
# 2       pl.10fc76a3edc14e759deb60535854e339               True
# 3       pl.0b593f1142b84a50a2c1e7088b3fb683               True
# 4       pl.299001f6c528460797ea61bac6522a81               True
# 5       pl.5ee8333dbe944d9f9151e97d92d1ead9               True
# 10      pl.6f8f8462368a46d984d0e2e61ac27c3c               True
# 11      pl.cc74a5aec23942da9cf083c6c4344aee               True
# 12                     pl.u-KVXBkl1ILAGrb4P               True
# 13      pl.a0c765aa555e457c9666b2a201de5506               True
# 14      pl.c03f886929854b5c99d44266b5c31b61               True
# 15                      pl.u-gxblkMRCE6qzLk               True
# 16      pl.8c2c23f9775a4e6a99a4d123ceb192a8               True
# 18      pl.aed19ba664d74829a8721bc1ffec6c48               True
# 20      pl.ae7c5093e09e49bcb60ec2a1fa2eec24               True
# 21                      pl.u-d2b0WVXsByRjXY               True
# 24      pl.b5046a8b64cd4c9493449c3af09ab396               True
# 27                       pl.rp-leeMIVxbGQBx               True
# 28      pl.b14f6d747a4e49b293eef8ea4bd57218               True
# 33      pl.775d03128173475c87e7b84ddf93d73c               True
# 41                      pl.u-PDb49rpIkxD9oR               True
# 42                      pl.u-WabZZy3cv9Kqmq               True
# 43                     pl.u-leyl0Jlhj09GL6D               True
# 45      pl.6af6e511d3e74e238d8d9510be9ddc85               True
# 46      pl.7008a3110f554cb7b2b2d864db3b9138               True
# 47   pl.pm-d5779e520ff52d7f7e597ced57e6f0e7               True
# 49      pl.de1a43425bce45149b9f0bb1b6c1eb7f               True
# 50                      pl.u-XkD03KRTNG3vp1               True
# 51      pl.abe8ba42278f4ef490e3a9fc5ec8e8c5               True
# 52      pl.5766fcca72a343babd559ff314531884               True
# 54   pl.pm-d5779e520ff52d7f61dc3fd63d45acc9               True
# 55                      pl.u-e98lkVjsZvpgJG               True
# 60      pl.8a5c858049354733a40349aabebca1b9               True
# 61      pl.449a3ddbbf8e4984b949f94b56ac744d               True
# 62      pl.aee6135fbed84ffdac8a4128c099124e               True
# 63      pl.d66feecbd40d423d81e8e643e368291a               True
# 64      pl.a342f7575bef42419401cd0618e0956a               True
# 65      pl.94e6d58e06ea47a4818bab7f39dd0c9f               True
# 66                      pl.u-pMyl1BMCx3MA57               True
# 67                     pl.u-d2b0kx2sMWXera6               True
# 74                      pl.u-9N9LXjbC2yeVrM               True
# 76                       pl.rp-zLL1iX0dWPb0               True
# 77      pl.6a2b374e861047bea93b8dfc40362b8a               True
# 78      pl.85f7e88157704ba6aec2365c3a2d7eaf               True
# 82      pl.1e6f5b2cc1914da48d5bb4f44aadedcb               True
# 84      pl.379de5da1cd24e959c08089b53ecaf4d               True
# 85      pl.e48b3541f37a4afd8171be6bee06c39e               True
# 86                     pl.u-e98lky5TzxJLqDx               True
# 87                     pl.u-9N9LX83Cx9vPYq9               True
# 91      pl.b35b2fdcac6a418a91522666bf2bf41b               True
# 96   pl.pm-d5779e520ff52d7f109ba521488a0033               True
# 99      pl.3b89144df9054dc3a8502c8a74cc1686               True
# 105     pl.fea117e7b45549aea9a0663d8a309806               True
#
#     Playlist Previously Shared Description Available On Apple Music Profile
# 1                         True         NaN                              NaN
# 2                         True         NaN                              NaN
# 3                         True         NaN                              NaN
# 4                         True         NaN                              NaN
# 5                         True         NaN                              NaN
# 10                        True         NaN                              NaN
# 11                        True         NaN                              NaN
# 12                        True         NaN                              NaN
# 13                        True         NaN                              NaN
# 14                        True         NaN                              NaN
# 15                        True         NaN                              NaN
# 16                        True         NaN                              NaN
# 18                        True         NaN                              NaN
# 20                        True         NaN                              NaN
# 21                        True         NaN                              NaN
# 24                        True         NaN                              NaN
# 27                        True         NaN                              NaN
# 28                        True         NaN                              NaN
# 33                        True         NaN                              NaN
# 41                        True         NaN                              NaN
# 42                        True         NaN                              NaN
# 43                        True         NaN                              NaN
# 45                        True         NaN                              NaN
# 46                        True         NaN                              NaN
# 47                        True         NaN                              NaN
# 49                        True         NaN                              NaN
# 50                        True         NaN                              NaN
# 51                        True         NaN                              NaN
# 52                        True         NaN                              NaN
# 54                        True         NaN                              NaN
# 55                        True         NaN                              NaN
# 60                        True         NaN                              NaN
# 61                        True         NaN                              NaN
# 62                        True         NaN                              NaN
# 63                        True         NaN                              NaN
# 64                        True         NaN                              NaN
# 65                        True         NaN                              NaN
# 66                        True         NaN                              NaN
# 67                        True         NaN                              NaN
# 74                        True         NaN                              NaN
# 76                        True         NaN                              NaN
# 77                        True         NaN                              NaN
# 78                        True         NaN                              NaN
# 82                        True         NaN                              NaN
# 84                        True         NaN                              NaN
# 85                        True         NaN                              NaN
# 86                        True         NaN                              NaN
# 87                        True         NaN                              NaN
# 91                        True         NaN                              NaN
# 96                        True         NaN                              NaN
# 99                        True         NaN                              NaN
# 105                       True         NaN                              NaN

# %%
df[df['Title'].isna()]['Container Type'].value_counts()
# Out:
# Container Type
# Subscribed Playlist    52
# Name: count, dtype: int64

# %%
df[df['Container Type'] == 'Favorites Playlist']['Title']
# Out:
# 0    Favorite Songs
# Name: Title, dtype: object

# %%
df[df['Favorite Status - Playlist'] == True]['Title']
# Out:
# 0     Favorite Songs
# 18               NaN
# Name: Title, dtype: object

# %%
df_personal = df[df['Container Type'] == 'Playlist']

# %%
df_personal.shape
# Out:
# (53, 14)

# %%
df_personal['Description'].isna().sum()
# Out:
# 10

# %%
df_personal['Title'].isna().sum()
# Out:
# 0

# %%
df_personal[df_personal['Playlist Is Shared'] == False]['Title']
# Out:
# 8              My Shazam Tracks
# 95     TRANSITION. No crossfade
# 97                     desi DnB
# 102                    DnB 🥁 SJ
# 103                    DnB 🥁 SJ
# 104                    DnB 🥁 SJ
# Name: Title, dtype: object

# %%
df_personal[df_personal['Playlist Previously Shared'] == True]['Title']
# Out:
# 6                              Bathroom
# 7                                   Club
# 19               13 reasons why personal
# 22                     Untitled Playlist
# 23                     Untitled Playlist
# 25                           Seedhe Maut
# 26                           Linkin Park
# 29                          Non Hip-Hop
# 30                                   DHH
# 31                        Hip-Hop / Trap
# 32                         Hip-Hop Outro
# 34                                   Alt
# 35                                   Emo
# 36                  Beat Switch Symphony
# 37     The Weeknd - After Hours Til Dawn
# 38                                     H
# 39        Atlantic Beats: Trap meets EDM
# 44                 Best Intros (Hip-Hop)
# 48                Best remixes (Hip-Hop)
# 57                          Indian Drill
# 58                     Relax on Hip-Hop
# 59                          Jersey Club
# 73                     Gujarati Hip-Hop
# 75             Dark&Scary Beats by Metro
# 83                     Library: Upcoming
# 88                           Video Songs
# 89             2016 XXL freshman cypher
# 90                       Guitar Hip-Hop
# 92                       Wake UP at 5 AM
# 93                               Elevate
# 94                           Rap Revival
# 98                       MikeDeanMagic 🌵
# 100                           3AreLegend
# 101                          Saved Songs
# Name: Title, dtype: object

# %%
df_personal[df_personal['Available On Apple Music Profile'] == True]['Title']
# Out:
# 30                                   DHH
# 31                        Hip-Hop / Trap
# 32                         Hip-Hop Outro
# 34                                   Alt
# 35                                   Emo
# 37     The Weeknd - After Hours Til Dawn
# 44                 Best Intros (Hip-Hop)
# 48                Best remixes (Hip-Hop)
# 57                          Indian Drill
# 58                     Relax on Hip-Hop
# 59                          Jersey Club
# 71                   Piano Hip-Hop Tunes
# 72                              Flute 🪈🪤
# 73                     Gujarati Hip-Hop
# 75             Dark&Scary Beats by Metro
# 90                       Guitar Hip-Hop
# 92                       Wake UP at 5 AM
# 93                               Elevate
# 94                           Rap Revival
# 98                       MikeDeanMagic 🌵
# 100                           3AreLegend
# 104                             DnB 🥁 SJ
# Name: Title, dtype: object

# %%
df['Favorite Date - Playlist'].value_counts()
# Out:
# Favorite Date - Playlist
# 2023-10-31T01:45:27Z    1
# Name: count, dtype: int64

# %%
df[df['Favorite Status - Playlist'] == True]['Title']
# Out:
# 0     Favorite Songs
# 18               NaN
# Name: Title, dtype: object

# %%
df_non_nans = df.isna().sum(axis=1)
min_len = df_non_nans.min()
min_len_idx = df_non_nans.idxmin()

# %%
mdown_text = f"""
# Library Playlists Data Definition

This data dictionary describes the fields in the {FILE_NAME} data. There are {df.shape[0]} rows and {df.shape[1]} columns. 

## Library Playlists Data

"""

# %%
def generate_markdown_table(df, min_index):
    # Helper function to map data types to more readable formats
    def map_data_type(dtype, sample_value):
        # Check for datetime
        if pd.api.types.is_datetime64_any_dtype(dtype) or (
            isinstance(sample_value, str) and pd.to_datetime(sample_value, errors='coerce') is not pd.NaT
        ):
            return "Datetime"
        # Check for Boolean (Python Boolean or string representation)
        elif isinstance(sample_value, bool) or (isinstance(sample_value, str) and sample_value.lower() in ["true", "false"]):
            return "Boolean"
        elif pd.api.types.is_string_dtype(dtype):
            return "String"
        elif pd.api.types.is_numeric_dtype(dtype):
            if pd.api.types.is_integer_dtype(dtype):
                return "Integer"
            elif pd.api.types.is_float_dtype(dtype):
                return "Float"
        elif isinstance(sample_value, list):
            return "List"
        else:
            return str(dtype)  # Fallback to original dtype if no match

    # Generate the table header
    markdown = "| Column Name | Data Type | Description | Example Value |\n"
    markdown += "|-------------|-----------|-------------|---------------|\n"

    # Iterate over DataFrame columns to generate each row
    for column in df.columns:
        sample_value = df[column].iloc[min_len_idx] if not df[column].empty else "N/A"
        data_type = map_data_type(df[column].dtype, sample_value)
        # Convert example_value to string to avoid formatting issues
        example_value = str(sample_value).replace("\n", " ").replace("|", "\\|")
        # Create a new row for each column
        markdown += f"| `{column}` | {data_type} |  | {example_value} |\n"

    return markdown

mdown_text += generate_markdown_table(df, min_len_idx)

# %%
def write_markdown_file(mdown_text, file_path):
    with open(file_path, 'w') as f:
        f.write(mdown_text)
    print(f"Markdown file saved to {file_path}")

# %%
write_markdown_file(mdown_text, os.path.join(DOCS_PATH, DOC_NAME))
# Out:
# Markdown file saved to ../docs/Library/LIBRARY_PLAYLISTS.md

# %%
df['Public Playlist Identifier'].isna().sum()
# Out:
# 17

# %%
df[df['Public Playlist Identifier'].isna()]['Title']
# Out:
# 0                            Favorite Songs
# 8                          My Shazam Tracks
# 9                                      Temp
# 17                                      you
# 40                                 Gujarati
# 53                                  Mixtape
# 56     Lil Baby & Young Thug - It's Only Me
# 68                                 Mask Off
# 69                         R&B and Hip-Hop
# 70                         i hate palo alto
# 79                         Hip-Hop top 2023
# 80                          Hip-Hop bangers
# 81                                        L
# 95                 TRANSITION. No crossfade
# 97                                 desi DnB
# 102                                DnB 🥁 SJ
# 103                                DnB 🥁 SJ
# Name: Title, dtype: object

# %% [markdown]
# ### Merge table with Library Tracks to get title of songs in the playlist

# %%
def load_data(FILE_PATH):
    with open(FILE_PATH, 'r') as f:
        data = json.load(f)
    return pd.DataFrame(data)

# %%
LIBRARY_TRACK_FILE = 'Apple Music Library Tracks.json'
df_tracks = load_data(os.path.join(DATA_PATH, LIBRARY_TRACK_FILE))

# %%
df_tracks.shape
# Out:
# (2761, 52)

# %%
df_exploded = df.explode('Playlist Item Identifiers')

# %%
df_exploded.shape
# Out:
# (2467, 14)

# %%
df_exploded.head()
# Out:
#        Container Type  Container Identifier           Title  \
# 0  Favorites Playlist                     2  Favorite Songs
# 0  Favorites Playlist                     2  Favorite Songs
# 0  Favorites Playlist                     2  Favorite Songs
# 0  Favorites Playlist                     2  Favorite Songs
# 0  Favorites Playlist                     2  Favorite Songs
#
#   Playlist Item Identifiers Favorite Status - Playlist  \
# 0                 182887450                       True
# 0                 182907166                       True
# 0                 182896434                       True
# 0                 182906674                       True
# 0                 182905398                       True
#
#   Favorite Date - Playlist            Added Date  \
# 0     2023-10-31T01:45:27Z  2023-04-26T04:35:27Z
# 0     2023-10-31T01:45:27Z  2023-04-26T04:35:27Z
# 0     2023-10-31T01:45:27Z  2023-04-26T04:35:27Z
# 0     2023-10-31T01:45:27Z  2023-04-26T04:35:27Z
# 0     2023-10-31T01:45:27Z  2023-04-26T04:35:27Z
#
#   Name or Description Modified Date Playlist Items Modified Date  \
# 0              2023-04-26T04:35:27Z         2024-09-27T04:56:46Z
# 0              2023-04-26T04:35:27Z         2024-09-27T04:56:46Z
# 0              2023-04-26T04:35:27Z         2024-09-27T04:56:46Z
# 0              2023-04-26T04:35:27Z         2024-09-27T04:56:46Z
# 0              2023-04-26T04:35:27Z         2024-09-27T04:56:46Z
#
#   Public Playlist Identifier Playlist Is Shared Playlist Previously Shared  \
# 0                        NaN                NaN                        NaN
# 0                        NaN                NaN                        NaN
# 0                        NaN                NaN                        NaN
# 0                        NaN                NaN                        NaN
# 0                        NaN                NaN                        NaN
#
#   Description Available On Apple Music Profile
# 0         NaN                              NaN
# 0         NaN                              NaN
# 0         NaN                              NaN
# 0         NaN                              NaN
# 0         NaN                              NaN

# %%
df_tracks['Track Identifier'].nunique()
# Out:
# 2761

# %%
df_with_tracks = pd.merge(df_exploded, df_tracks[['Track Identifier', 'Title']], how='left', left_on='Playlist Item Identifiers', right_on='Track Identifier')

# %%
df_with_tracks.head()
# Out:
#        Container Type  Container Identifier         Title_x  \
# 0  Favorites Playlist                     2  Favorite Songs
# 1  Favorites Playlist                     2  Favorite Songs
# 2  Favorites Playlist                     2  Favorite Songs
# 3  Favorites Playlist                     2  Favorite Songs
# 4  Favorites Playlist                     2  Favorite Songs
#
#   Playlist Item Identifiers Favorite Status - Playlist  \
# 0                 182887450                       True
# 1                 182907166                       True
# 2                 182896434                       True
# 3                 182906674                       True
# 4                 182905398                       True
#
#   Favorite Date - Playlist            Added Date  \
# 0     2023-10-31T01:45:27Z  2023-04-26T04:35:27Z
# 1     2023-10-31T01:45:27Z  2023-04-26T04:35:27Z
# 2     2023-10-31T01:45:27Z  2023-04-26T04:35:27Z
# 3     2023-10-31T01:45:27Z  2023-04-26T04:35:27Z
# 4     2023-10-31T01:45:27Z  2023-04-26T04:35:27Z
#
#   Name or Description Modified Date Playlist Items Modified Date  \
# 0              2023-04-26T04:35:27Z         2024-09-27T04:56:46Z
# 1              2023-04-26T04:35:27Z         2024-09-27T04:56:46Z
# 2              2023-04-26T04:35:27Z         2024-09-27T04:56:46Z
# 3              2023-04-26T04:35:27Z         2024-09-27T04:56:46Z
# 4              2023-04-26T04:35:27Z         2024-09-27T04:56:46Z
#
#   Public Playlist Identifier Playlist Is Shared Playlist Previously Shared  \
# 0                        NaN                NaN                        NaN
# 1                        NaN                NaN                        NaN
# 2                        NaN                NaN                        NaN
# 3                        NaN                NaN                        NaN
# 4                        NaN                NaN                        NaN
#
#   Description Available On Apple Music Profile  Track Identifier  \
# 0         NaN                              NaN       182887450.0
# 1         NaN                              NaN       182907166.0
# 2         NaN                              NaN       182896434.0
# 3         NaN                              NaN       182906674.0
# 4         NaN                              NaN       182905398.0
#
#               Title_y
# 0           Forget It
# 1            KILL DEM
# 2         PROBLEMATIC
# 3  F*CK WHAT THEY SAY
# 4     where will i be

# %%
df['Title'].unique()
# Out:
# array(['Favorite Songs', nan, 'Bathroom ', 'Club', 'My Shazam Tracks',
#        'Temp', 'you', '13 reasons why personal', 'Untitled Playlist',
#        'Seedhe Maut', 'Linkin Park', 'Non Hip-Hop ', 'DHH',
#        'Hip-Hop / Trap', 'Hip-Hop Outro', 'Alt', 'Emo',
#        'Beat Switch Symphony', 'The Weeknd - After Hours Til Dawn', 'H',
#        'Atlantic Beats: Trap meets EDM', 'Gujarati',
#        'Best Intros (Hip-Hop)', 'Best remixes (Hip-Hop)', 'Mixtape',
#        "Lil Baby & Young Thug - It's Only Me", 'Indian Drill',
#        'Relax on Hip-Hop ', 'Jersey Club ', 'Mask Off',
#        'R&B and Hip-Hop ', 'i hate palo alto', 'Piano Hip-Hop Tunes',
#        'Flute \U0001fa88🪤', 'Gujarati Hip-Hop ',
#        'Dark&Scary Beats by Metro', 'Hip-Hop top 2023', 'Hip-Hop bangers',
#        'L', 'Library: Upcoming', 'Video Songs',
#        '2016 XXL freshman cypher ', 'Guitar Hip-Hop ', 'Wake UP at 5 AM',
#        'Elevate', 'Rap Revival', 'TRANSITION. No crossfade', 'desi DnB',
#        'MikeDeanMagic 🌵', '3AreLegend', 'Saved Songs', 'DnB 🥁 SJ'],
#       dtype=object)

# %%
list(df_with_tracks[df_with_tracks['Title_x'] == 'MikeDeanMagic 🌵']['Title_y'])
# Out:
# ['HIGHEST IN THE ROOM',
#  'For The Night (feat. Lil Baby & DaBaby)',
#  '90210 (feat. Kacy Hill)',
#  'Ni**as in Paris',
#  'goosebumps',
#  '5% TINT',
#  'Stronger',
#  'pick up the phone',
#  'NO BYSTANDERS',
#  'STOP TRYING TO BE GOD',
#  'Father Stretch My Hands, Pt. 1',
#  'SICKO MODE (Skrillex Remix)',
#  'SICKO MODE',
#  'Panda',
#  'Power',
#  'BUTTERFLY EFFECT',
#  'Antidote',
#  'HYAENA',
#  'Watch (feat. Lil Uzi Vert & Kanye West)',
#  'STARGAZING',
#  'Hurricane',
#  "CAN'T SAY",
#  'FE!N (feat. Playboi Carti)',
#  'YOSEMITE',
#  'THANK GOD',
#  'MY EYES',
#  'FRANCHISE (feat. Young Thug & M.I.A.)',
#  'Power is Power',
#  'The Plan (From the Motion Picture "TENET")',
#  'All of the Lights',
#  'Am I Dreaming',
#  'Young Metro',
#  'Popular (feat. Playboi Carti) [Music from the HBO Original Series The Idol]',
#  'Double Fantasy (feat. Future)',
#  'TOP FLOOR (feat. Travis Scott)',
#  'Annihilate (Spider-Man: Across the Spider-Verse)',
#  'Flocky Flocky (feat. Travis Scott)',
#  'Oh Me Oh My (feat. Travis Scott, Migos & G4shi)',
#  'Never Sleep (feat. Travis Scott)',
#  'Way Bigger',
#  'Frankenstein',
#  'Danielle (smile on my face)',
#  'K-POP (feat. Bad Bunny & The Weeknd)',
#  'CIRCUS MAXIMUS (feat. The Weeknd & Swae Lee)',
#  'You (feat. Travis Scott)',
#  'All Of The Lights (Interlude)',
#  'On Again',
#  'Cocoon (Martin Garrix & Space Ducks Remix)',
#  'Moth To A Flame',
#  'HIGHEST IN THE ROOM (REMIX) [feat. ROSALÍA & Lil Baby]',
#  'WHAT TO DO? (feat. Don Toliver)',
#  'JACKBOYS',
#  'HOUSTONFORNICATION',
#  'CODE',
#  'Solitaires (feat. Travis Scott)',
#  'MAFIA',
#  'No Idea',
#  'Wild for the Night (feat. Skrillex & Birdy Nam Nam)',
#  'I KNOW ?',
#  'TELEKINESIS (feat. SZA & Future)',
#  'Black Skinhead']

# %%
df_exploded.shape, df_with_tracks.shape
# Out:
# ((2467, 14), (2467, 16))

# %%
df_with_tracks['Title_y'].isna().sum()
# Out:
# 55

# %%
df_with_tracks[df_with_tracks['Title_y'] == 'Mixtape']['Title_x'].unique()
# Out:
# array([], dtype=object)

# %%
df[df['Title'] == 'Mixtape']
# Out:
#    Container Type  Container Identifier    Title  \
# 53       Playlist             256002829  Mixtape
#
#                        Playlist Item Identifiers Favorite Status - Playlist  \
# 53  [182880802, 182870558, 182880806, 182880798]                        NaN
#
#    Favorite Date - Playlist            Added Date  \
# 53                      NaN  2022-12-20T18:50:39Z
#
#    Name or Description Modified Date Playlist Items Modified Date  \
# 53              2022-12-20T18:50:40Z         2022-12-20T18:50:40Z
#
#    Public Playlist Identifier Playlist Is Shared Playlist Previously Shared  \
# 53                        NaN                NaN                        NaN
#
#    Description Available On Apple Music Profile
# 53                                          NaN

# %%
df_exploded[df_exploded['Title'] == 'Mixtape']
# Out:
#    Container Type  Container Identifier    Title Playlist Item Identifiers  \
# 53       Playlist             256002829  Mixtape                 182880802
# 53       Playlist             256002829  Mixtape                 182870558
# 53       Playlist             256002829  Mixtape                 182880806
# 53       Playlist             256002829  Mixtape                 182880798
#
#    Favorite Status - Playlist Favorite Date - Playlist            Added Date  \
# 53                        NaN                      NaN  2022-12-20T18:50:39Z
# 53                        NaN                      NaN  2022-12-20T18:50:39Z
# 53                        NaN                      NaN  2022-12-20T18:50:39Z
# 53                        NaN                      NaN  2022-12-20T18:50:39Z
#
#    Name or Description Modified Date Playlist Items Modified Date  \
# 53              2022-12-20T18:50:40Z         2022-12-20T18:50:40Z
# 53              2022-12-20T18:50:40Z         2022-12-20T18:50:40Z
# 53              2022-12-20T18:50:40Z         2022-12-20T18:50:40Z
# 53              2022-12-20T18:50:40Z         2022-12-20T18:50:40Z
#
#    Public Playlist Identifier Playlist Is Shared Playlist Previously Shared  \
# 53                        NaN                NaN                        NaN
# 53                        NaN                NaN                        NaN
# 53                        NaN                NaN                        NaN
# 53                        NaN                NaN                        NaN
#
#    Description Available On Apple Music Profile
# 53                                          NaN
# 53                                          NaN
# 53                                          NaN
# 53                                          NaN

# %%
df_with_tracks[df_with_tracks['Title_x'] == 'Mixtape']
# Out:
#      Container Type  Container Identifier  Title_x Playlist Item Identifiers  \
# 1841       Playlist             256002829  Mixtape                 182880802
# 1842       Playlist             256002829  Mixtape                 182870558
# 1843       Playlist             256002829  Mixtape                 182880806
# 1844       Playlist             256002829  Mixtape                 182880798
#
#      Favorite Status - Playlist Favorite Date - Playlist  \
# 1841                        NaN                      NaN
# 1842                        NaN                      NaN
# 1843                        NaN                      NaN
# 1844                        NaN                      NaN
#
#                 Added Date Name or Description Modified Date  \
# 1841  2022-12-20T18:50:39Z              2022-12-20T18:50:40Z
# 1842  2022-12-20T18:50:39Z              2022-12-20T18:50:40Z
# 1843  2022-12-20T18:50:39Z              2022-12-20T18:50:40Z
# 1844  2022-12-20T18:50:39Z              2022-12-20T18:50:40Z
#
#      Playlist Items Modified Date Public Playlist Identifier  \
# 1841         2022-12-20T18:50:40Z                        NaN
# 1842         2022-12-20T18:50:40Z                        NaN
# 1843         2022-12-20T18:50:40Z                        NaN
# 1844         2022-12-20T18:50:40Z                        NaN
#
#      Playlist Is Shared Playlist Previously Shared Description  \
# 1841                NaN                        NaN
# 1842                NaN                        NaN
# 1843                NaN                        NaN
# 1844                NaN                        NaN
#
#      Available On Apple Music Profile  Track Identifier  \
# 1841                              NaN       182880802.0
# 1842                              NaN       182870558.0
# 1843                              NaN       182880806.0
# 1844                              NaN       182880798.0
#
#                                      Title_y
# 1841                      Meri Pant Bhi Sexy
# 1842  Way 2 Sexy (feat. Future & Young Thug)
# 1843                                Sanam Re
# 1844                                 Whoopty

# %%
df_tracks['Playlist Only Track'].value_counts()
# Out:
# Playlist Only Track
# True     300
# False    173
# Name: count, dtype: int64

# %%
df_tracks.shape
# Out:
# (2761, 52)

# %%
list(df_tracks[df_tracks['Playlist Only Track'] == True]['Title'])
# Out:
# ['2 Phút Hơn (KAIZ Remix)',
#  'UCLA',
#  "I Don't Like (feat. Lil Reese)",
#  'Everytime We Touch (Hardwell & Maurice West Remix)',
#  'Everytime We Touch (Radio Edit)',
#  'Opus (Four Tet Remix)',
#  'Riot Gear',
#  'Hall of Fame (feat. will.i.am)',
#  'Friendships',
#  "It's Time",
#  'Feelings',
#  'Eat the Beat',
#  'Then Leave (feat. Queendome Come)',
#  'Boom, Boom, Boom, Boom!!',
#  'Body (feat. brando) [Mixed]',
#  "Day N' Night (feat. ZHIKO)",
#  'In My Moog (The Art of Seq)',
#  'Trump It',
#  'Yonaguni',
#  'Body (Dzeko Extended Remix)',
#  'Body (Dzeko Remix)',
#  'Laser House',
#  'FL.EX (Flow Experience)',
#  'Roses',
#  'Body (feat. brando) [Chus & Ceballos Remix]',
#  'Body (feat. brando) [Live]',
#  'Swing',
#  'Poker Face (Space Cowboy Remix)',
#  "What's Next",
#  'Moment 4 Life (feat. Drake)',
#  'seaside_demo',
#  'Hearts on Fire',
#  'How Do I Make You Love Me?',
#  "Can't Feel My Face",
#  'Or Nah (feat. The Weeknd, Wiz Khalifa and DJ Mustard) [Remix]',
#  'Party Monster',
#  'Faith',
#  'I Feel It Coming (feat. Daft Punk)',
#  'Is There Someone Else?',
#  'I Was Never There',
#  'Wicked Games',
#  'The Morning',
#  'Infinity',
#  'FRANCHISE (feat. Young Thug & M.I.A.)',
#  'Hot (Remix) [feat. Gunna and Travis Scott]',
#  'No Type',
#  'We Are Not the Same',
#  'Lord Pretty Flacko Jodye 2 (LPFJ2)',
#  'Tussin (feat. Young Thug)',
#  'WHO? WHAT!',
#  'Roses (feat. ROZES)',
#  'Rattle',
#  'Get Up (Rattle) [feat. Far East Movement] [Vocal Edit]',
#  'Story Of My Life (feat. Trippie Redd) [Heavy Edit]',
#  'Me Myself & Adderall (feat. Goody Grace)',
#  'Sweat (Snoop Dogg vs. David Guetta) [Remix]',
#  'My Truck (feat. Sam Hunt) [Remix]',
#  'Sweet Caroline',
#  'too easy',
#  'Moti Veraana (From Songs of Faith) [feat. Osman Mir]',
#  'Kamariya',
#  'Gori Radha Ne Kado Kaan',
#  'Chogada (From "Loveyatri")',
#  'Shubhaarambh',
#  'Chogada (Unplugged)',
#  'Nagada Sang Dhol',
#  'Dakla 2 (feat. Aishwarya Joshi & Maulik Nayak) [Video Edit]',
#  'Lifestyle',
#  'Hello (Awiin Remix)',
#  'Clout (feat. Cardi B)',
#  'Grove St. Party (feat. Kebo Gotti)',
#  'Dreams and Nightmares',
#  'Plain Jane (Remix) [feat. Nicki Minaj]',
#  'All the Way Up (feat. Infared)',
#  'ROOF',
#  'Masterpiece',
#  'Budget (feat. Latto)',
#  'I Leave Again',
#  'Meri Pant Bhi Sexy',
#  'Sanam Re',
#  'In A Minute',
#  'Similar',
#  'Dark Hearted',
#  'From Now On (feat. Future)',
#  'Quickie',
#  'Just Wanna Rock',
#  'Hanging With Wolves',
#  'Bars Into Captions',
#  'Mad Max',
#  'Backstage Passes (feat. Jack Harlow)',
#  'Stay Awake (feat. Lil Uzi Vert)',
#  'Ma Boy',
#  'Silent Hill',
#  'MUSCLES',
#  'King Snipe',
#  "Pressin' (feat. Quavo & Moneybagg Yo)",
#  'The Magic Number',
#  'Sharing Locations (feat. Lil Baby & Lil Durk)',
#  'GO!',
#  'Nothing Changed',
#  'Do It Again (feat. Summer Cem)',
#  'Hear It Back (feat. Moneybagg Yo)',
#  '2040',
#  '300 Blackout',
#  'Superhero (Heroes & Villains)',
#  'Gangsta Boo',
#  'My All',
#  'Ambition For Cash',
#  'Thats How',
#  'DARK BROTHERHOOD',
#  'All The Money (Bonus)',
#  'Lately',
#  "JOC IN '06",
#  'Needed That',
#  'LIKE ME (feat. 42 Dugg & Lil Baby)',
#  'Tomorrow 2',
#  'PUFFIN ON ZOOTIEZ',
#  'Right On',
#  'LLC (feat. Moneybagg Yo)',
#  'California Breeze',
#  'KAPITOL DENIM',
#  'Forever',
#  'BLOW UP',
#  'Switches & Dracs (feat. Lil Durk & EST Gee)',
#  'What Happened To Virgil (Apple Music Live)',
#  'On Wat U On',
#  'N95',
#  'See Wat I’m Sayin',
#  'Blessing',
#  'In Ha Mood',
#  'King Size',
#  'Nobody Special',
#  'Burning Up (feat. The Kid LAROI)',
#  'Pissed Me Off',
#  'Shottas (Lala)',
#  'RATATAAAAA',
#  'Black',
#  'First Time',
#  'Super Gremlin',
#  "Don't Play With It (feat. Billy B)",
#  '2 LIVE',
#  "I Ain't Mad At Cha (feat. Danny Boy)",
#  'Never Sleep (feat. Travis Scott)',
#  'Certified (feat. Gunna)',
#  'Black Visa (feat. Moneybagg Yo)',
#  'Dah Dah DahDah',
#  'Distraction',
#  'Plenty',
#  'Internet Trolls (feat. Hitkidd)',
#  'Stop Breathing',
#  'Frozen',
#  'Walk',
#  'Twin (feat. Lil Durk)',
#  'Rookie of the Year',
#  'Heyy',
#  'Everybody Shooters Too',
#  'Sleazy Flow (feat. Lil Baby) [Remix]',
#  'Love For The Streets',
#  'Dirty Soul',
#  'Blow',
#  'Rumors (feat. Lil Durk)',
#  'Jigsaw',
#  'Real As It Gets (feat. EST Gee)',
#  'Wonderful Wayne & Jackie Boy',
#  'Players',
#  'Gaah',
#  "STAR WALKIN' (League of Legends Worlds Anthem)",
#  'All of the Lights (Interlude)',
#  'New Money',
#  'Run It (Jersey Club Mix)',
#  'Sticky',
#  'Mask Off (Marshmello Remix)',
#  'All of the Lights (Interlude)',
#  'Boom Boom',
#  'Darth Vader',
#  'Umbrella',
#  'Close My Eyes',
#  "God's Plan",
#  'Bodak Yellow',
#  'rockstar (feat. 21 Savage)',
#  'Points of Authority / 99 Problems / One Step Closer',
#  'A$aP Rocky (Praise the Lord (Da Shine)) [Tsunam1_ Remix]',
#  'Lose Yourself',
#  'Super Bass',
#  'No Problem (feat. Lil Wayne & 2 Chainz)',
#  'Hey Ya! (Radio Mix/Club Mix)',
#  'good 4 u',
#  'Kiss Me More (feat. SZA)',
#  'Butter',
#  'Happier Than Ever',
#  'MONTERO (Call Me By Your Name)',
#  'positions',
#  'Preparty Till We Meet',
#  'Jackie Chan (feat. Preme & Post Malone)',
#  'Metro Spider',
#  'Cold Water (feat. Justin Bieber & MØ)',
#  'Let Me Love You (feat. Justin Bieber)',
#  'Spaceman',
#  "Don't Let Me Down (feat. Daya)",
#  'Firestone (feat. Conrad Sewell)',
#  'Thinking Out Loud',
#  'Light of the Seven',
#  'FRANCHISE (feat. Young Thug & M.I.A.)',
#  'Sicko Mode (feat. Drake)',
#  'Butterfly Effect',
#  'First Person Shooter (feat. J. Cole)',
#  'YOSEMITE',
#  'WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil Wayne) [Remix]',
#  'A Lot (feat. J. Cole)',
#  'Lucid Dreams',
#  'HIGHEST IN THE ROOM',
#  'GATTI',
#  'OUT WEST (feat. Young Thug)',
#  'Lemonade (Remix) [Lyric Video]',
#  '10:35',
#  'After Hours',
#  'Chennai Bass (feat. Sivamani & Chinna Ponnu)',
#  'F**K Nucleya',
#  'Bass Rani',
#  'Mumbai Dance (feat. Julius Sylvest & Gagan Mudgal)',
#  'F*ck Jump Up (feat. B Live)',
#  'Gravity',
#  'Ready To Fly (Sub Focus & Dimension)',
#  'Shag',
#  'Realise',
#  'Never B Mine',
#  'This Moment',
#  'Afterglow',
#  'I Found You (feat. HAYLA)',
#  'Selecta (feat. Stefflon Don)',
#  'Infinity (feat. ILIRA, iiola & Tom Cane)',
#  'Baddadan (feat. IRah, Flowdan, Trigga & Takura)',
#  'Wasted Youth',
#  'Lowkey (LDN Drift) [feat. Takura]',
#  'Tough Talk (feat. Kwengface)',
#  'DJ Turn It Up',
#  'Fine Day',
#  'Waiting (feat. Kelli-Leigh)',
#  'Back Bus',
#  'Hooked (Grafix Remix)',
#  'No Excuses',
#  'Feel Again',
#  'Closer (feat. Slay) [Hedex Remix]',
#  'Jungle (Arcando Remix)',
#  'Off The Ground',
#  'Rhyme Dust (Dimension Remix)',
#  'Chase the Sun',
#  'Rock It (Wilkinson Remix)',
#  'Delete (feat. Burro Banton)',
#  'High Note (feat. Emily Makis)',
#  'Together',
#  'WORTH NOTHING (feat. Oliver Tree) [Fast & Furious: Drift Tape/Phonk, Vol 1]',
#  'Calling For A Sign (feat. Kelli-Leigh)',
#  'Liquor & Cigarettes (feat. ArrDee)',
#  'Move Your Body (Hedex Remix)',
#  'Love To Give (with Culture Shock & Billy Lockett)',
#  'Solar System',
#  'Where Do We Go (feat. Poppy Baskcomb)',
#  'go (goddard. Remix)',
#  'Siren',
#  'On The Block (feat. Savo & Horrid1)',
#  'Tell Me Why (1991 Remix)',
#  'Tour',
#  'Strong (High Contrast Remix)',
#  'MHITR (Semi-Automatic) [feat. Eksman]',
#  'Let Go',
#  'Offender',
#  'Gtfu',
#  'Go Like (D&B Remix)',
#  'Against the Tide',
#  'Green & Gold (feat. Charlotte Plank & Riko Dan)',
#  'Halfway Down (Matrix & Futurebound Remix) [feat. Ashley Drake]',
#  'Lost My Mind',
#  'Danger (Reaper Remix)',
#  'Supersonic (Basstripper Remix)',
#  'Mr Happy',
#  'Gold Dust',
#  'Menticide (Teddy Killerz Remix)',
#  'The Saucer',
#  'Go Back',
#  'Voice Notes (Serum Remix)',
#  'On My Mind',
#  'Pachamama (feat. Elliphant)',
#  'Click Clack',
#  "Ain't No Way 2024",
#  'Rave Out',
#  'Haunted VIP',
#  "It's That Time (Dimension Remix)",
#  'Rave Is Life',
#  "Don't Stop",
#  'Immortal',
#  'Eyes on Me',
#  'Miracle (Reaper Remix)',
#  'Power',
#  'Click Click Click',
#  'Pump It (D&B)',
#  'Big City Life',
#  'Trigga Finga (feat. Trigga)',
#  "Laserbeam (Blanke's ÆON:REMIX)",
#  'Arjan Vailly (From "Animal")']

# %%
list(df_tracks[df_tracks['Playlist Only Track'] == False]['Title'])
# Out:
# ['Pray For Me',
#  'Lucid Dreams',
#  'ROCKSTAR (feat. Roddy Ricch)',
#  'Lemonade (feat. NAV)',
#  'Mask Off (Marshmello Remix)',
#  'Save Your Tears',
#  'Like I Do',
#  'Blessings (feat. Drake)',
#  'Mo Bamba',
#  'Centuries',
#  'More Than You Know',
#  'The Box',
#  'Forbidden Voices',
#  'Stay A While',
#  'Travis Scott  INTERSTELLAR ft Frank Ocean Hans Zimmer',
#  'INTERSTELLAR',
#  'goosebumps (Time Remix)',
#  'WhatsApp Audio 2021-11-25 at 7.05.22 PM',
#  'Never Say Goodbye',
#  "We'll Be Coming Yee (Hardwell",
#  'The Island (Tiesto Remix)',
#  'Stereo Love (Extend Version)',
#  'Lose Myself vs. Fifteen (Hardw',
#  'Dare You (Extended Mix)',
#  'If I Lose Myself (Alesso vs OneRepublic)',
#  'How We Do vs. Summertime Sadne',
#  'Welcome To The Jungle vs. Lepr',
#  'Live For The Spaceman (Hardwel',
#  'Pallaroid vs. Arise vs. I Coul',
#  'Apollo (Hardwell Private Conce',
#  'The Code vs. Alive vs. Harder',
#  'Years vs. Cannonball vs. Anima',
#  'Jumper',
#  'Alive Thunder (Hardwell Mashup',
#  'Avicii - Silhouettes',
#  'Calvin Harris feat. Ellie Goulding - I Need Your Love',
#  'Dare You - Hardwell',
#  'Dimitri Vegas & Like Mike - Wakanda',
#  'Dimitri Vegas &amp; Like Mike vs W&amp;W - Waves (Tomorrowland 2014 Anthem)',
#  'Dimitri Vegas & Like Mike feat. Boostedkids - G.I.P.S.Y (Original Mix)',
#  "Ain't a Party [Radio Edit]",
#  'DVLM - Stampede (Original Mix)',
#  'Spaceman (Original Mix)',
#  'Fade Into Darkness (Official Vocal Edit)',
#  'Fifteen (Hardwell Edit)',
#  'Goldskies (Official Music)',
#  'Just One Last Time - David Guetta',
#  'Madness (Yves V Remix)',
#  'Lights & Thunder (feat. Gareth Emery)',
#  'Never Say Goodbye (Feat. Bright Lights) (Original Mix)',
#  'honey singh mix[het]NONSTOP',
#  'Animals (Original Mix)',
#  'Booyah (feat. We Are Loud! & Sonny Wilson)',
#  'honey singh mix[het]NONSTOP',
#  'Drugs You Should Try It',
#  'Astronomical',
#  'We Are Legend ft. Abigail Breslin',
#  'Alone Again',
#  'Sacrifice',
#  'Take My Breath',
#  'Hurricane',
#  'The Hills',
#  'Crew Love (feat. The Weeknd)',
#  'Starboy (feat. Daft Punk)',
#  'Heartless',
#  'Kiss Land',
#  'After Hours',
#  'Out of Time',
#  'Less Than Zero',
#  "DON'T GET CAUGHT (feat. Travis Scott & Young Thug)",
#  'NEVER SLEEP 2.0 (REMIX)',
#  'FAIR TRADE 2.0',
#  'N95 (feat. Travis Scott)',
#  'HOUSTONFORNICATION',
#  'Pnp',
#  'New Choppa (feat. A$AP Rocky)',
#  'Uss Din',
#  'Time Machine (feat. Drake)',
#  'SUPERSONIC (feat. Travis Scott, Quavo & Takeoff)',
#  'KNIFE PART II',
#  'ZOOM V2',
#  'ESCAPE PLAN 2.0',
#  'BOOM (feat. Gucci Mane)',
#  'The Half (feat. Jeremih, Young Thug & Swizz Beatz)',
#  'Remember The Name (feat. Eminem & 50 Cent)',
#  'too easy (Remix) [feat. Future & Roddy Ricch]',
#  '13 INTERSTELLAR',
#  '02 SOLITAIRES',
#  'Plain Jane',
#  'Treacherous Twins',
#  'One More Time',
#  'On Time',
#  'Whoopty',
#  'Cold Heart (Acoustic)',
#  'Trance (ft. Drake)',
#  'zaeden - tere bina (lost stories remix feat. yashraj)',
#  'EUPHORIA - MAERI (LOST STORIES EDIT)',
#  'why this kolaveri male',
#  'We will rock you',
#  'One Direction - Best song ever (Lyrics and Pictures) (NEW SONG 2013)_low',
#  '02_ Six Days The Remix',
#  'One Love',
#  'Rumble',
#  'Saza-E-Maut (feat. Raftaar)',
#  'Gujarati Bapu',
#  'Satya',
#  'Way Back',
#  'Way Back',
#  'just wanna rock [ hard techno / hardstlye remix ]',
#  'Drip Too Hard (Jersey Club Mix)',
#  'Superhero (Heroes & Villains)',
#  'Heart On My Sleeve (AI Generated) | Arewamh.Com.Ng',
#  'nocta_TK12511126.mp3',
#  'Mamacita (feat. Rich Homie Quan & Young Thug)',
#  'True Stories',
#  'SKRILLEX - QUEST FOR FIRE Basement Set',
#  'Fred Again x SHM x Future - Turn On The Lights (Knock2 Remix)',
#  'Knock2, Fred again.. - Turn On The Lights again.. (Jack Ross DNB Edit)',
#  'HUMBLE.',
#  'Interstellar x Where You Are x Reload (MashBit Mashup)',
#  'Massive (KREAM Remix) [Extended Mix]',
#  'Moth To A Flame (KREAM Remix) [Extended Mix]',
#  'Ego Death (KREAM Remix) [Extended Mix]',
#  'After Hours (KREAM Remix) [Extended Mix]',
#  'Laugh Now Cry Later ft. Lil Durk (KREAM Remix) [Extended Mix]',
#  'Running Up That Hill (KREAM Remix) [Extended Mix]',
#  'THE SCOTTS (KREAM Remix) [Extended Mix]',
#  'Boppenheimer (Aaron Hibell Trance Extended Mix)',
#  'Oppenheimer X Interstellar EMOTIONAL VERSION (Can You Hear the Music X Cornfield Chase) [TubeRipper.com]',
#  'Interstellar Theme EPIC Version [TubeRipper.com]',
#  'hibell-glued-2-deep-in-time-aaron-hibell-edit_456242184',
#  'Denver',
#  'Pepper',
#  'Flip It (feat. Dem Jointz)',
#  'Sexy Bitch (feat. Akon)',
#  'The Days',
#  'Summer',
#  'Rockabye (feat. Sean Paul & Anne-Marie)',
#  "Don't You Worry Child (Radio Edit) [feat. John Martin]",
#  'Somebody Like U',
#  'Five More Hours',
#  'Wake Me Up',
#  'Hillana',
#  'The London (feat. J. Cole & Travis Scott)',
#  'Just Wanna Rock',
#  'Blood on My Jeans',
#  'leavemealone',
#  'Private Landing (feat. Justin Bieber & Future)',
#  'Drip Too Hard / Intro / Rumble / My Mind (Loud Luxury Edit) [Mixed]',
#  "GOOD (DON'T DIE)",
#  'STARS',
#  'Gehraiyaan',
#  'stayinit',
#  'Mai Ni Meriye (feat. Jonita Gandhi & Ashwin Adwani)',
#  'En Retour',
#  'Precision',
#  'Red Leather',
#  'Laung Gawacha (feat. Avneet Khurmi)',
#  '7 Minute Drill',
#  'Taylor Made Freestyle (feat 2Pac, Snoop Dogg)',
#  'b378992f203f4ed994d90a84c2169c83.HD-1080p-2.5Mbps-27697379',
#  "Shot O'clock",
#  'Old Days',
#  'BANDIT',
#  'Three Little Birds',
#  'Would You (go to bed with me?) [MGB Edit]',
#  'Used to This',
#  'Miracle (Wilkinson Remix)',
#  'Bruises',
#  'BURN IT DOWN (Tom Swoon Remix)',
#  'A LIGHT THAT NEVER COMES (Rick Rubin Reboot)',
#  'A LIGHT THAT NEVER COMES',
#  'F*CK WHAT THEY SAY']

# %%
df['Container Identifier'].isna().sum()
# Out:
# 0

# %%
df['Container Identifier'].nunique()
# Out:
# 106

# %%
df.shape
# Out:
# (106, 14)

# %%
# Rename Title_x to Title and Title_y to Tracks Title
df_with_tracks.rename(columns={'Title_x': 'Title', 'Title_y': 'Tracks Title'}, inplace=True)

# %%
df_with_tracks.columns
# Out:
# Index(['Container Type', 'Container Identifier', 'Title',
#        'Playlist Item Identifiers', 'Favorite Status - Playlist',
#        'Favorite Date - Playlist', 'Added Date',
#        'Name or Description Modified Date', 'Playlist Items Modified Date',
#        'Public Playlist Identifier', 'Playlist Is Shared',
#        'Playlist Previously Shared', 'Description',
#        'Available On Apple Music Profile', 'Track Identifier', 'Tracks Title'],
#       dtype='object')

# %%
df_with_tracks['Title']
# Out:
# 0       Favorite Songs
# 1       Favorite Songs
# 2       Favorite Songs
# 3       Favorite Songs
# 4       Favorite Songs
#              ...
# 2462          DnB 🥁 SJ
# 2463          DnB 🥁 SJ
# 2464          DnB 🥁 SJ
# 2465          DnB 🥁 SJ
# 2466               NaN
# Name: Title, Length: 2467, dtype: object

# %%
df_with_tracks['Tracks Title']
# Out:
# 0                            Forget It
# 1                             KILL DEM
# 2                          PROBLEMATIC
# 3                   F*CK WHAT THEY SAY
# 4                      where will i be
#                      ...
# 2462                        Eyes on Me
# 2463                          Mr Happy
# 2464                       Click Clack
# 2465    Laserbeam (Blanke's ÆON:REMIX)
# 2466                               NaN
# Name: Tracks Title, Length: 2467, dtype: object

# %%
# Automatically create the aggregation dictionary
aggregation_dict = {col: 'first' for col in df_with_tracks.columns if col not in ['Title', 'Tracks Title', 'Playlist Item Identifiers']}
aggregation_dict['Tracks Title'] = list
aggregation_dict['Playlist Item Identifiers'] = list

# Group by 'playlist_id' and apply the aggregation
df_merged = df_with_tracks.groupby('Title').agg(aggregation_dict).reset_index()

# %%
df_merged.head()
# Out:
#                             Title Container Type  Container Identifier  \
# 0         13 reasons why personal       Playlist             256001041
# 1       2016 XXL freshman cypher        Playlist             256004625
# 2                      3AreLegend       Playlist             256005377
# 3                             Alt       Playlist             256001809
# 4  Atlantic Beats: Trap meets EDM       Playlist             256002065
#
#   Favorite Status - Playlist Favorite Date - Playlist            Added Date  \
# 0                       None                     None  2021-08-06T06:45:18Z
# 1                       None                     None  2024-01-04T06:53:44Z
# 2                       None                     None  2024-05-03T05:42:39Z
# 3                       None                     None  2022-04-29T09:44:09Z
# 4                       None                     None  2022-09-10T22:32:38Z
#
#   Name or Description Modified Date Playlist Items Modified Date  \
# 0              2021-08-06T06:45:56Z         2021-08-06T06:46:18Z
# 1              2024-01-04T06:54:58Z         2024-01-04T06:54:58Z
# 2              2024-05-03T05:42:43Z         2024-05-03T05:50:42Z
# 3              2022-04-29T09:44:10Z         2022-07-21T00:14:13Z
# 4              2023-05-25T20:01:24Z         2023-10-17T18:27:54Z
#
#   Public Playlist Identifier Playlist Is Shared Playlist Previously Shared  \
# 0       pl.u-aZb0N64tPBe640B               True                       True
# 1       pl.u-mJy88aPtzX3P17X               True                       True
# 2       pl.u-76oNP26CW5l6z05               True                       True
# 3       pl.u-e98lkMLizxJLqDx               True                       True
# 4       pl.u-9N9LX83Cx9vPYq9               True                       True
#
#                                          Description  \
# 0                            13 reasons why personal
# 1  Denzel Curry, Lil Uzi Vert, Lil Yachty, 21 Sav...
# 2                                               None
# 3
# 4       Collaboration of the both sides of Atlantic.
#
#   Available On Apple Music Profile  Track Identifier  \
# 0                             None       182863410.0
# 1                             None       182890250.0
# 2                             True       182874902.0
# 3                             True       182872850.0
# 4                             None       182871350.0
#
#                                         Tracks Title  \
# 0  [f**k, i'm lonely (feat. Anne-Marie), The Nigh...
# 1                                      [Yessirskiii]
# 2  [Bubbly (with Drake & Travis Scott), Nanchaku,...
# 3  [When I R.I.P., All for Us (From the HBO Origi...
# 4  [SICKO MODE (Skrillex Remix), HUMBLE. (SKRILLE...
#
#                            Playlist Item Identifiers
# 0  [182863410, 182863878, 182863158, 182863654, 1...
# 1                                        [182890250]
# 2  [182874902, 182862890, 182890290, 182879514, 1...
# 3  [182872850, 182872342, 182872326, 182872322, 1...
# 4  [182871350, 182878214, 182861870, 182885150, 1...
