# %%
import pandas as pd
import polars as pl
import os

# %%
DATA_PATH = os.path.join('../Apple Music Activity')
FILE_NAME = 'Apple Music - Play History Daily Tracks.csv'

# %%
lf = (
    pl.scan_csv(os.path.join(DATA_PATH, FILE_NAME))
    .with_columns(
        pl.col("Date Played")
        .cast(pl.Utf8)
        .str.strptime(pl.Date, format="%Y%m%d")
        .alias("date_played"),
        (pl.col("Play Duration Milliseconds")/(1000*60*60))
        .alias("play_duration_hours"),
        (pl.col("Play Duration Milliseconds")/(1000*60))
        .alias("play_duration_minutes")
    )
)

# %%
lf
# Out:
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div> WITH_COLUMNS:<p></p> [col("Date Played").strict_cast(String).str.strptime(["raise"]).alias("date_played"), [(col("Play Duration Milliseconds")) / (3600000)].alias("play_duration_hours"), [(col("Play Duration Milliseconds")) / (60000)].alias("play_duration_minutes")] <p></p>  Csv SCAN [../Apple Music Activity/Apple Music - Play History Daily Tracks.csv]<p></p>  PROJECT */13 COLUMNS<p></p>  ESTIMATED ROWS: 98004</div>

# %%
pl.scan_csv(os.path.join(DATA_PATH, FILE_NAME)).schema
# Out:
# /var/folders/yt/wtkcgjsn4wsfn6t4pg_rfy080000gn/T/ipykernel_71993/3806941023.py:1: PerformanceWarning: Resolving the schema of a LazyFrame is a potentially expensive operation. Use `LazyFrame.collect_schema()` to get the schema without this warning.
#   pl.scan_csv(os.path.join(DATA_PATH, FILE_NAME)).schema
# Schema([('Country', String),
#         ('Track Identifier', Int64),
#         ('Media type', String),
#         ('Date Played', Int64),
#         ('Hours', String),
#         ('Play Duration Milliseconds', Int64),
#         ('End Reason Type', String),
#         ('Source Type', String),
#         ('Play Count', Int64),
#         ('Skip Count', Int64),
#         ('Ignore For Recommendations', Boolean),
#         ('Track Reference', String),
#         ('Track Description', String)])

# %%
lf_2025 = lf.filter(pl.col("date_played").dt.year() == 2025)

# %%
df_2025 = lf_2025.collect()

# %%
df_2025
# Out:
# shape: (11_314, 16)
# ┌────────────┬────────────┬───────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Country    ┆ Track      ┆ Media ┆ Date       ┆ … ┆ Track Des ┆ date_play ┆ play_dura ┆ play_dura │
# │ ---        ┆ Identifier ┆ type  ┆ Played     ┆   ┆ cription  ┆ ed        ┆ tion_hour ┆ tion_minu │
# │ str        ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---       ┆ ---       ┆ s         ┆ tes       │
# │            ┆ i64        ┆ str   ┆ i64        ┆   ┆ str       ┆ date      ┆ ---       ┆ ---       │
# │            ┆            ┆       ┆            ┆   ┆           ┆           ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪═══════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ United     ┆ 1737150439 ┆ AUDIO ┆ 20250101   ┆ … ┆ Future,   ┆ 2025-01-0 ┆ 0.127696  ┆ 7.661767  │
# │ States     ┆            ┆       ┆            ┆   ┆ Metro     ┆ 1         ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ Boomin &  ┆           ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ Kendric…  ┆           ┆           ┆           │
# │ United     ┆ 1747373147 ┆ AUDIO ┆ 20250101   ┆ … ┆ Fred      ┆ 2025-01-0 ┆ 0.125691  ┆ 7.541483  │
# │ States     ┆            ┆       ┆            ┆   ┆ again..,  ┆ 1         ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ Anderson  ┆           ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ .Paak &…  ┆           ┆           ┆           │
# │ United     ┆ 1440887515 ┆ AUDIO ┆ 20250101   ┆ … ┆ Playboi   ┆ 2025-01-0 ┆ 0.119406  ┆ 7.164333  │
# │ States     ┆            ┆       ┆            ┆   ┆ Carti -   ┆ 1         ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ Magnolia  ┆           ┆           ┆           │
# │ United     ┆ 1687215995 ┆ AUDIO ┆ 20250101   ┆ … ┆ Lil Durk  ┆ 2025-01-0 ┆ 0.113588  ┆ 6.8153    │
# │ States     ┆            ┆       ┆            ┆   ┆ - All My  ┆ 1         ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ Life      ┆           ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ (feat. …  ┆           ┆           ┆           │
# │ United     ┆ 1760997262 ┆ AUDIO ┆ 20250101   ┆ … ┆ ¥$, Kanye ┆ 2025-01-0 ┆ 0.073439  ┆ 4.406367  │
# │ States     ┆            ┆       ┆            ┆   ┆ West & Ty ┆ 1         ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ Dolla     ┆           ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ $ign…     ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …     ┆ …          ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ United     ┆ 1480847207 ┆ AUDIO ┆ 20250504   ┆ … ┆ Lauv -    ┆ 2025-05-0 ┆ 0.0       ┆ 0.0       │
# │ States     ┆            ┆       ┆            ┆   ┆ Modern    ┆ 4         ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ Lonelines ┆           ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ s         ┆           ┆           ┆           │
# │ United     ┆ 1103026967 ┆ AUDIO ┆ 20250504   ┆ … ┆ RL Grime  ┆ 2025-05-0 ┆ 0.0       ┆ 0.0       │
# │ States     ┆            ┆       ┆            ┆   ┆ - Aurora  ┆ 4         ┆           ┆           │
# │ United     ┆ 1158846625 ┆ AUDIO ┆ 20250504   ┆ … ┆ Pritam,   ┆ 2025-05-0 ┆ 0.0       ┆ 0.0       │
# │ States     ┆            ┆       ┆            ┆   ┆ Abhijeet  ┆ 4         ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ Sawant &  ┆           ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ Adit…     ┆           ┆           ┆           │
# │ United     ┆ 1683978546 ┆ AUDIO ┆ 20250504   ┆ … ┆ Mawi - No ┆ 2025-05-0 ┆ 0.0       ┆ 0.0       │
# │ States     ┆            ┆       ┆            ┆   ┆ Love      ┆ 4         ┆           ┆           │
# │ United     ┆ 1608974445 ┆ AUDIO ┆ 20250504   ┆ … ┆ JBEE -    ┆ 2025-05-0 ┆ 0.0       ┆ 0.0       │
# │ States     ┆            ┆       ┆            ┆   ┆ Next Up - ┆ 4         ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ S4-E2,    ┆           ┆           ┆           │
# │            ┆            ┆       ┆            ┆   ┆ Pt. 1     ┆           ┆           ┆           │
# └────────────┴────────────┴───────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# use the collected (eager) DataFrame and Polars group_by/agg syntax
top_songs_2025 = (
    df_2025
    .group_by('Track Description')
    .agg([
        pl.col('play_duration_minutes').sum().alias("total_minutes"),
        pl.col('Play Count').sum().alias('total_play_count')
    ])
    .sort('total_minutes', descending=True)
    .limit(10)
)

# %%
top_songs_2025
# Out:
# shape: (10, 3)
# ┌─────────────────────────────────┬───────────────┬──────────────────┐
# │ Track Description               ┆ total_minutes ┆ total_play_count │
# │ ---                             ┆ ---           ┆ ---              │
# │ str                             ┆ f64           ┆ i64              │
# ╞═════════════════════════════════╪═══════════════╪══════════════════╡
# │ The Weeknd - Cry For Me         ┆ 131.49145     ┆ 39               │
# │ Daft Punk - Contact             ┆ 77.6999       ┆ 16               │
# │ Playboi Carti & The Weeknd - R… ┆ 75.700783     ┆ 26               │
# │ ¥$, Kanye West & Ty Dolla $ign… ┆ 73.7893       ┆ 22               │
# │ Drake & 21 Savage - Spin Bout … ┆ 70.552417     ┆ 19               │
# │ The Weeknd & Anitta - São Paul… ┆ 67.431333     ┆ 16               │
# │ The Weeknd - Earned It (Fifty … ┆ 65.960483     ┆ 15               │
# │ The Weeknd & Playboi Carti - T… ┆ 65.440583     ┆ 17               │
# │ Kx5, deadmau5 & Kaskade - Esca… ┆ 62.989083     ┆ 18               │
# │ Kendrick Lamar - Not Like Us    ┆ 59.79015      ┆ 16               │
# └─────────────────────────────────┴───────────────┴──────────────────┘

# %%
# top = top_songs_2025.collect()

# %%
print (top_songs_2025)
# Out:
# shape: (10, 3)
# ┌─────────────────────────────────┬───────────────┬──────────────────┐
# │ Track Description               ┆ total_minutes ┆ total_play_count │
# │ ---                             ┆ ---           ┆ ---              │
# │ str                             ┆ f64           ┆ i64              │
# ╞═════════════════════════════════╪═══════════════╪══════════════════╡
# │ The Weeknd - Cry For Me         ┆ 131.49145     ┆ 39               │
# │ Daft Punk - Contact             ┆ 77.6999       ┆ 16               │
# │ Playboi Carti & The Weeknd - R… ┆ 75.700783     ┆ 26               │
# │ ¥$, Kanye West & Ty Dolla $ign… ┆ 73.7893       ┆ 22               │
# │ Drake & 21 Savage - Spin Bout … ┆ 70.552417     ┆ 19               │
# │ The Weeknd & Anitta - São Paul… ┆ 67.431333     ┆ 16               │
# │ The Weeknd - Earned It (Fifty … ┆ 65.960483     ┆ 15               │
# │ The Weeknd & Playboi Carti - T… ┆ 65.440583     ┆ 17               │
# │ Kx5, deadmau5 & Kaskade - Esca… ┆ 62.989083     ┆ 18               │
# │ Kendrick Lamar - Not Like Us    ┆ 59.79015      ┆ 16               │
# └─────────────────────────────────┴───────────────┴──────────────────┘

# %% [markdown]
# ### April 2025

# %%
lf_apr = (
    pl.scan_csv(os.path.join(DATA_PATH, 'Apple Music - Play History Daily Tracks April 2025.csv'))
    .with_columns(
        (pl.col("Play Duration Milliseconds")/(1000*60*60))
        .alias("play_duration_hours"),
        (pl.col("Play Duration Milliseconds")/(1000*60))
        .alias("play_duration_minutes")
    )
)

# %%
lf_apr
# Out:
# <i>naive plan: (run <b>LazyFrame.explain(optimized=True)</b> to see the optimized plan)</i>
#     <p></p>
#     <div> WITH_COLUMNS:<p></p> [[(col("Play Duration Milliseconds")) / (3600000)].alias("play_duration_hours"), [(col("Play Duration Milliseconds")) / (60000)].alias("play_duration_minutes")] <p></p>  Csv SCAN [../Apple Music Activity/Apple Music - Play History Daily Tracks April 2025.csv]<p></p>  PROJECT */15 COLUMNS<p></p>  ESTIMATED ROWS: 1546</div>

# %%
top_song_apr = (
    lf_apr
    .group_by('Track Description')
    .agg([
        # pl.col('play_duration_minutes').sum().alias('total_minutes'),
        pl.col('Play Count').sum().alias('total_plays')
    ])
    .sort('total_plays', descending=True)
    .limit(11)
)

# %%
top_song_apr.collect()
# Out:
# shape: (11, 2)
# ┌─────────────────────────────────┬─────────────┐
# │ Track Description               ┆ total_plays │
# │ ---                             ┆ ---         │
# │ str                             ┆ i64         │
# ╞═════════════════════════════════╪═════════════╡
# │ Daft Punk - Contact             ┆ 15          │
# │ Martin Garrix & Arijit Singh -… ┆ 15          │
# │ Billie Eilish - WILDFLOWER      ┆ 13          │
# │ THE ANXIETY, WILLOW & Tyler Co… ┆ 11          │
# │ Mismatched - Cast & Sickflip -… ┆ 10          │
# │ …                               ┆ …           │
# │ Skrillex & Dj Smokey - SKRILLE… ┆ 9           │
# │ Ramin Djawadi - The Prince Tha… ┆ 8           │
# │ The Chainsmokers - Paris        ┆ 8           │
# │ Drake - 9                       ┆ 7           │
# │ Skrillex, Virtual Riot & Nakee… ┆ 7           │
# └─────────────────────────────────┴─────────────┘

# %%
daily_hours = (
    lf_2025
    .group_by('Date Played')
    .agg([
        pl.col('play_duration_hours').sum().alias('total_hours')
    ])
    .sort('Date Played')
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 3
#       1 daily_hours = (
#       2     lf_2025
# ----> 3     .groupby('Date Played')
#       4     .agg([
#       5         pl.col('play_duration_hours').sum().alias('total_hours')
#       6     ])
#       7     .sort('Date Played')
#       8 )
#
# AttributeError: 'LazyFrame' object has no attribute 'groupby'

# %%
print (daily_hours.collect())
# Out:
# shape: (123, 2)
# ┌─────────────┬─────────────┐
# │ Date Played ┆ total_hours │
# │ ---         ┆ ---         │
# │ i64         ┆ f64         │
# ╞═════════════╪═════════════╡
# │ 20250101    ┆ 2.8945325   │
# │ 20250102    ┆ 1.420362    │
# │ 20250103    ┆ 8.223111    │
# │ 20250104    ┆ 5.070216    │
# │ 20250105    ┆ 5.58934     │
# │ …           ┆ …           │
# │ 20250430    ┆ 2.725068    │
# │ 20250501    ┆ 4.670846    │
# │ 20250502    ┆ 3.536968    │
# │ 20250503    ┆ 3.462501    │
# │ 20250504    ┆ 2.892364    │
# └─────────────┴─────────────┘

# %%
def load_song_history(file_path: str) -> pl.LazyFrame:
    return (
        pl.scan_csv(file_path)
        .with_columns(
            pl.col('Date Played')
            .cast(pl.Utf8)
            .str.strptime()
        )
    )
